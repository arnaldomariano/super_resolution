# %% [markdown]
# ## Import Modules

# %%
import cv2
from cv2 import dnn_superres
from cv2 import imshow

# %%
# links to download models
# https://github.com/Saafke/EDSR_Tensorflow/blob/master/models/
# https://github.com/fannymonori/TF-LapSRN/blob/master/export/LapSRN_x8.pb

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install my_model
# Out:
# Collecting my_model
#   Downloading my_model-0.3-py3-none-any.whl (963 bytes)
# Installing collected packages: my_model
# Successfully installed my_model-0.3

# %% [markdown]
# ##**Original Image**

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load the image
image = cv2.imread('/content/drive/MyDrive/SuperRes/test.jpg')

# Verificar se a imagem foi carregada corretamente
if image is None:
    print("Erro ao carregar a imagem. Verifique se o caminho do arquivo está correto.")
else:
    print("Imagem carregada com sucesso.")
# Out:
# Imagem carregada com sucesso.

# %%
# Load the image
imagem = cv2.imread('/content/drive/MyDrive/SuperRes/test.jpg')

# Verificar se a imagem foi carregada corretamente
if imagem is not None:
    # Obter as dimensões da imagem
    altura, largura, _ = imagem.shape

# Imprimir as dimensões
print("Dimensões da foto:", largura, "x", altura)

# Show image
cv2_imshow(imagem)# Imagem original
# Out:
# Dimensões da foto: 48 x 48
# <PIL.Image.Image image mode=RGB size=48x48>

# %% [markdown]
# ## EDSR

# %%
from google.colab.patches import cv2_imshow

# initialize super resolution object
sr = dnn_superres.DnnSuperResImpl_create()

# read the model
path = '/content/drive/MyDrive/SuperRes/EDSR_x4.pb'
sr.readModel(path)

# set the model and scale
sr.setModel('edsr', 4)

# %%
# Check if the image was loaded correctly
if image is None:
    print("Erro ao carregar a imagem.")
else:
    # Upsample of image
    upscaled = sr.upsample(image)

    # Verify if the upscaled image was created correctly.
    if upscaled is not None:

        # Salvar a imagem upscaled
        cv2.imwrite('upscaled_test.jpg', upscaled)
        print("Imagem upscaled salva com sucesso.")
    else:
        print("Erro ao criar a imagem upscaled.")
# Out:
# Imagem upscaled salva com sucesso.

# %%
# Load the image
image = cv2.imread('upscaled_test.jpg')

# Verificar se a imagem foi carregada corretamente
if imagem is not None:
    # Obter as dimensões da imagem
    altura, largura, _ = imagem.shape

#Show image
cv2_imshow(upscaled)# Image upscaled 4x

# Imprimir as dimensões
print("Dimensões da foto:", largura, "x", altura)
# Out:
# <PIL.Image.Image image mode=RGB size=192x192>
# Dimensões da foto: 48 x 48

# %%
from google.colab.patches import cv2_imshow

# initialize super resolution object
sr = dnn_superres.DnnSuperResImpl_create()

# read the model
path = '/content/drive/MyDrive/SuperRes/LapSRN_x4.pb'
sr.readModel(path)

# set the model and scale
sr.setModel('lapsrn', 4)

# %%
# Check if the image was loaded correctly
if image is None:
    print("Erro ao carregar a imagem.")
else:
    # Upsample da imagem
    upscaled_test_2 = sr.upsample(image)

    # Verify if the upscaled image was created correctly
    if upscaled is not None:

        #  Save the upscaled image
        cv2.imwrite('upscaled_test_2.jpg', upscaled)

        print("Imagem upscaled_test_2 salva com sucesso.")
    else:
        print("Erro ao criar a imagem upscaled_test_2")
# Out:
# Imagem upscaled_test_2 salva com sucesso.

# %%
# Load the image
image = cv2.imread('upscaled_test_2.jpg')

# Verificar se a imagem foi carregada corretamente
if imagem is not None:
    # Obter as dimensões da imagem
    altura, largura, _ = imagem.shape

#Show image
cv2_imshow(upscaled_test_2)# Image upscaled 4x with LapSRN_x4

# Imprimir as dimensões
print("Dimensões da foto:", largura, "x", altura)
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>
# Dimensões da foto: 48 x 48

# %% [markdown]
# ##**Method Bicubic**

# %%
# upsample the image
bicubic = sr.upsample(image)
# save the upscaled image
cv2.imwrite('upscaled_test_2.jpg', upscaled)
# Out:
# True

# %%
# traditional method - bicubic
bicubic = cv2.resize(image, (upscaled.shape[1], upscaled.shape[0]), interpolation=cv2.INTER_CUBIC)
# save the image
cv2.imwrite('bicubic_test.jpg', bicubic)
# Out:
# True

# %%
# Load the image
image = cv2.imread('upscaled_test_2.jpg')

# Verificar se a imagem foi carregada corretamente
if imagem is not None:
    # Obter as dimensões da imagem
    altura, largura, _ = imagem.shape

#Show image
cv2_imshow(bicubic)# Image upscaled with LapSRN_x4

# Imprimir as dimensões
print("Dimensões da foto:", largura, "x", altura)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>
# Dimensões da foto: 192 x 192

# %% [markdown]
# ## **LapSRN**

# %%
# initialize super resolution object
sr = dnn_superres.DnnSuperResImpl_create()

# read the model
path = '/content/drive/MyDrive/SuperRes/LapSRN_x8.pb'
sr.readModel(path)

# set the model and scale
sr.setModel('lapsrn', 8)

# %%
# load the image
image = cv2.imread('test.jpg')

# %%
# Carregar a imagem
image = cv2.imread('/content/drive/MyDrive/SuperRes/test.jpg')


# Verificar se a imagem foi carregada corretamente
if image is None:
    print("Erro ao carregar a imagem.")
else:
    # Upsample of image
    upscaled_Lap_8 = sr.upsample(image)

    # Verificar se a imagem upscaled foi criada corretamente
    if upscaled is not None:

        # Salvar a imagem upscaled
        cv2.imwrite('upscaled_Lap_8.jpg', upscaled)

        print("Imagem upscaled_Lap_8 salva com sucesso.")
    else:
        print("Erro ao criar a imagem upscaled_Lap_8")
# Out:
# Imagem upscaled_Lap_8 salva com sucesso.

# %%
# Load the image
image = cv2.imread('upscaled_Lap_8.jpg')

# Verificar se a imagem foi carregada corretamente
if imagem is not None:
    # Obter as dimensões da imagem
    altura, largura, _ = imagem.shape

cv2_imshow(upscaled_Lap_8)

# Imprimir as dimensões
print("Dimensões da foto:", largura, "x", altura)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>
# Dimensões da foto: 192 x 192

# %%
# upsample the image
upscaled = sr.upsample(image)
# save the upscaled image
cv2.imwrite('upscaled_test2_lapsrn.jpg', upscaled)
# Out:
# True

# %%
import numpy as np

# Verificar se a imagem upscaled foi criada corretamente
if upscaled is not None:
    print("Imagem upscaled criada com sucesso.")

    # Aplicar desfocagem para reduzir a falta de foco
    unblurred_test = cv2.blur(upscaled, (2, 2))  # Você pode ajustar o tamanho do kernel conforme necessário

    # Salvar a imagem desfocada
    cv2.imwrite('unblurred_test.jpg', unblurred_test)

    print("Imagem desfocada salva com sucesso.")
else:
    print("Erro ao criar a imagem upscaled_and_unblurred_test.jpg.")
# Out:
# Imagem upscaled criada com sucesso.
# Imagem desfocada salva com sucesso.

# %%
cv2_imshow(unblurred_test)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %%
# traditional method - bicubic
bicubic = cv2.resize(image, (upscaled.shape[1], upscaled.shape[0]), interpolation=cv2.INTER_CUBIC)
# save the image
cv2.imwrite('bicubic_test_8x.png', bicubic)
# Out:
# True

# %%
from google.colab.patches import cv2_imshow

# traditional method - bicubic
bicubic = cv2.resize(image, (upscaled.shape[1], upscaled.shape[0]), interpolation=cv2.INTER_CUBIC)

# exibir a imagem usando cv2_imshow
cv2_imshow(bicubic)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %%
pip install opencv-python-headless numpy
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.9.0.80)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carregar a imagem borrada
imagem_borrada = cv2.imread('upscaled_Lap_8.jpg', 0)  # 0 para carregar em escala de cinza

# Calcular a Transformada de Fourier da imagem
fourier = np.fft.fft2(imagem_borrada)
fourier_shifted = np.fft.fftshift(fourier)  # Colocar as baixas frequências no centro

# Calcular a magnitude do espectro de Fourier (espectro de frequência)
magnitude_spectrum = np.log(np.abs(fourier_shifted) + 1)  # Adicionar 1 para evitar log(0)

# Visualizar o espectro de frequência
plt.subplot(121), plt.imshow(imagem_borrada, cmap='gray')
plt.title('Imagem Borrada'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Espectro de Frequência'), plt.xticks([]), plt.yticks([])
plt.show()

# Aplicar um filtro gaussiano para realçar as altas frequências
filtro_gaussiano = cv2.getGaussianKernel(imagem_borrada.shape[0], 100)
filtro_gaussiano_2D = filtro_gaussiano * filtro_gaussiano.T
filtro_aplicado = fourier_shifted * filtro_gaussiano_2D

# Calcular a Transformada Inversa de Fourier
imagem_desfocada = np.fft.ifft2(np.fft.ifftshift(filtro_aplicado))
imagem_desfocada = np.abs(imagem_desfocada)

# Visualizar a imagem desfocada
plt.imshow(imagem_desfocada, cmap='gray')
plt.title('Imagem Desfocada'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57beb6ddac36> in <cell line: 5>()
#       3
#       4 # Carregar a imagem borrada
# ----> 5 imagem_borrada = cv2.imread('upscaled_Lap_8.jpg', 0)  # 0 para carregar em escala de cinza
#       6
#       7 # Calcular a Transformada de Fourier da imagem
#
# NameError: name 'cv2' is not defined

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load Blur image
imagem_borrada = cv2.imread('upscaled_Lap_8.jpg', 0)  # 0 para carregar em escala de cinza

# Calculate the Fourier Transform of the image.
fourier = np.fft.fft2(imagem_borrada)
fourier_shifted = np.fft.fftshift(fourier)  # Colocar as baixas frequências no centro

# Calculate the magnitude of the Fourier spectrum (frequency spectrum).
magnitude_spectrum = np.log(np.abs(fourier_shifted) + 1)  # Adicionar 1 para evitar log(0)

# Visualize the frequency spectrum.
plt.subplot(121), plt.imshow(imagem_borrada, cmap='gray')
plt.title('Imagem Borrada'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Espectro de Frequência'), plt.xticks([]), plt.yticks([])
plt.show()

# Adjust the parameters of the Gaussian filter.
tamanho_kernel = 15
desvio_padrao = 5

# Apply a Gaussian filter to enhance the high frequencies.
filtro_gaussiano = cv2.getGaussianKernel(tamanho_kernel, desvio_padrao)
filtro_gaussiano_2D = np.outer(filtro_gaussiano, filtro_gaussiano)  # 2D kernel

# Redimensionar o filtro gaussiano 2D para o mesmo tamanho que o espectro de Fourier
#The goal is for both to have the same dimensions.
filtro_gaussiano_2D = cv2.resize(filtro_gaussiano_2D, (fourier_shifted.shape[0], fourier_shifted.shape[1]))

# Resize the 2D Gaussian filter to the same size as the Fourier spectrum
filtro_aplicado = fourier_shifted * filtro_gaussiano_2D

# Calculate the Inverse Fourier Transform
imagem_desfocada = np.fft.ifft2(np.fft.ifftshift(filtro_aplicado))
imagem_desfocada = np.abs(imagem_desfocada)

# Visualize the blurred image.
plt.imshow(imagem_desfocada, cmap='gray')
plt.title('Imagem Desfocada'), plt.xticks([]), plt.yticks([])
plt.show()
cv2_imshow(unblurred_test)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %%
'''import cv2

# Carregar a imagem
imagem = cv2.imread('/content/drive/MyDrive/SuperRes/test.jpg')

# Verificar se a imagem foi carregada corretamente
if imagem is not None:
    # Obter as dimensões da imagem
    altura, largura, _ = imagem.shape

    # Imprimir as dimensões
    print("Dimensões da foto:", largura, "x", altura)

    # Exibir a imagem original
    #cv2.imshow('Imagem Original', imagem)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Erro ao carregar a imagem. Verifique o caminho e o nome do arquivo.")
'''
# Out:
# Dimensões da foto: 48 x 48
